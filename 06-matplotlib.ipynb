# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[1,4,2,3]

# %%
fig,ax=plt.subplots()
ax.plot(x,y)
ax.set_xlabel('变量a')
ax.set_ylabel('entry b')
plt.show()
# Out:
# C:\Users\张雨婷\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\张雨婷\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
