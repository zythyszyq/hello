# %%
import pandas as pd

# 加载数据
file_path = R'data\多元回归分析演示数据.xlsx'
数据表 = pd.read_excel(file_path)

# 显示数据的前几行以进行初步检查
数据表.head()
# Out:
#    福利措施  同侪关系  适应学习  创新学习  知识获取  知识流通  知识创新  财务控管  顾客认同  内部运作  学习成长  组织效能
# 0     7     8     7     5     9     8     6     5     5     5     5    20
# 1    11    10    17    13    15     7     4     5     5     5     5    20
# 2     9    10     7     8    20    16    13     6    10     6     5    27
# 3    12    14    14     9    19    14     4     5    12     7     5    29
# 4    12    13     7    13    22    18    14     5     5    10     9    29

# %%
import statsmodels.api as sm
# 使用指定的五个变量作为自变量进行多元线性回归分析
specified_variables = ['知识获取', '内部运作', '适应学习', '学习成长', '知识创新','顾客认同']
X_specified = 数据表[specified_variables]
y = 数据表['组织效能']  # 因变量

# 多元线性回归
X_specified_with_constant = sm.add_constant(X_specified)  
model_specified = sm.OLS(y, X_specified_with_constant).fit()

# 显示回归结果
model_specified_summary = model_specified.summary()
model_specified_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   组织效能   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     5516.
# Date:                Thu, 14 Dec 2023   Prob (F-statistic):               0.00
# Time:                        11:18:59   Log-Likelihood:                -2706.9
# No. Observations:                1200   AIC:                             5428.
# Df Residuals:                    1193   BIC:                             5464.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5670      0.409      3.833      0.000       0.765       2.369
# 知识获取           0.0408      0.020      2.009      0.045       0.001       0.081
# 内部运作           1.2715      0.042     30.166      0.000       1.189       1.354
# 适应学习           0.0435      0.022      1.963      0.050    1.83e-05       0.087
# 学习成长           1.0685      0.034     31.437      0.000       1.002       1.135
# 知识创新           0.0170      0.033      0.514      0.607      -0.048       0.082
# 顾客认同           1.4285      0.037     38.780      0.000       1.356       1.501
# ==============================================================================
# Omnibus:                       39.004   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.647
# Skew:                           0.205   Prob(JB):                     2.27e-17
# Kurtosis:                       4.168   Cond. No.                         312.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
