# %%
# 导入各种需要的包
import pandas as pd
import mytools
# from pyreadstat import pyreadstat

# %%
# 打开数据文件

df1 = pd.read_csv(R'data/类别变量练习数据.csv',encoding='GBK')

# %%
# 计算tauy
tau_y = mytools.goodmanKruska_tau_y(df1,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# c:\Users\张雨婷\Desktop\hello\mytools.py:79: RuntimeWarning: invalid value encountered in scalar divide
#   E_2 += ((F_x - f) * f) / F_x
# c:\Users\张雨婷\Desktop\hello\mytools.py:79: RuntimeWarning: divide by zero encountered in scalar divide
#   E_2 += ((F_x - f) * f) / F_x
# nan

# %%
# 评价tauy
mytools.相关系数强弱判断(tau_y)
# Out:
# '极弱相关或无相关'

# %%
import matplotlib.pyplot as plt  
import pandas as pd  
  
def plot_variable_pie(data_table, variable):  
    # 准备绘图数据
    data = data_table[variable].value_counts()  
      
    # 创建饼图  
    fig1, ax1 = plt.subplots()  
    ax1.pie(data, labels = data.index, autopct='%1.1f%%')  
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.  

    plt.title('Pie Chart of' + variable)
    plt.show()

# %%
df1['父亲职业重新编码'].value_counts()
# Out:
# 父亲职业重新编码
# 公务员     22
# 民企      14
# 个体       8
# 国企       4
# 事业单位     2
# 家庭主妇     2
# 家庭父亲     1
# Name: count, dtype: int64

# %%
df1['母亲职业重新编码'].value_counts()
# Out:
# 母亲职业重新编码
# 公务员     14
# 家庭主妇    11
# 事业单位     9
# 个体       7
# 民企       6
# 国企       2
# 上市民企     1
# 无        1
# 民企       1
# Name: count, dtype: int64

# %%
import mytools  
df1 = pd.read_csv("data/类别变量练习数据.csv", encoding='GBK')
plot_variable_pie(df1,'父亲职业重新编码')

# %%
import mytools  
df1 = pd.read_csv("data/类别变量练习数据.csv", encoding='GBK')
plot_variable_pie(df1,'母亲职业重新编码')

# %%
mytools.制作交叉表(df1, '父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企        个体      事业单位       公务员   国企      家庭主妇    无        民企  \
# 父亲职业重新编码
# 个体         0.0  0.571429  0.000000  0.000000  0.0  0.272727  0.0  0.000000
# 事业单位       0.0  0.000000  0.222222  0.000000  0.0  0.000000  0.0  0.000000
# 公务员        0.0  0.142857  0.666667  0.714286  0.5  0.000000  0.0  0.666667
# 国企         0.0  0.142857  0.000000  0.000000  0.5  0.090909  0.0  0.166667
# 家庭主妇       0.0  0.000000  0.000000  0.000000  0.0  0.181818  0.0  0.000000
# 家庭父亲       0.0  0.000000  0.000000  0.071429  0.0  0.000000  0.0  0.000000
# 民企         1.0  0.142857  0.111111  0.214286  0.0  0.454545  1.0  0.166667
#
# 母亲职业重新编码  民企        All
# 父亲职业重新编码
# 个体        0.0  0.134615
# 事业单位      0.0  0.038462
# 公务员       0.0  0.423077
# 国企        0.0  0.076923
# 家庭主妇      0.0  0.038462
# 家庭父亲      0.0  0.019231
# 民企        1.0  0.269231
